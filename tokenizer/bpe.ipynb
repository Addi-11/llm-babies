# 1. count the number of unique pairs in the text
# 2. merge the pair->idx..in ids list
# 3. choose number of merges, n merge

# %%
import regex as re
GPT4_SPLIT_PATTERN = r"""'(?i:[sdmt]|ll|ve|re)|[^\r\n\p{L}\p{N}]?+\p{L}+|\p{N}{1,3}| ?[^\s\p{L}\p{N}]++[\r\n]*|\s*[\r\n]|\s+(?!\S)|\s+"""

x = re.compile(GPT4_SPLIT_PATTERN)
text = re.findall(x, "why is this so annoying?? Ain't it pain!! BRAIN-404")
print("Regex split text: \t\t", text)

byte = [x.encode("utf-8") for x in text]
print("Text converted bytes: \t\t", byte)

tokens = [list(x.encode("utf-8")) for x in text]
print("List of Tokens for each bytes: \t", tokens)

dummy_txt = "wht is this?"
list(dummy_txt.encode("utf-8"))
# Out:
# Regex split text: 		 ['why', ' is', ' this', ' so', ' annoying', '??', ' Ain', "'t", ' it', ' pain', '!!', ' BRAIN', '-', '404']
# Text converted bytes: 		 [b'why', b' is', b' this', b' so', b' annoying', b'??', b' Ain', b"'t", b' it', b' pain', b'!!', b' BRAIN', b'-', b'404']
# List of Tokens for each bytes: 	 [[119, 104, 121], [32, 105, 115], [32, 116, 104, 105, 115], [32, 115, 111], [32, 97, 110, 110, 111, 121, 105, 110, 103], [63, 63], [32, 65, 105, 110], [39, 116], [32, 105, 116], [32, 112, 97, 105, 110], [33, 33], [32, 66, 82, 65, 73, 78], [45], [52, 48, 52]]
# [119, 104, 116, 32, 105, 115, 32, 116, 104, 105, 115, 63]

# %%
import pandas as pd

test_text = pd.read_csv('test.csv')
test_text = test_text[:5000]

sample_text = ' '.join(test_text['article'])

print(len(test_text))
test_text.head()
# Out:
# 5000
#                                             headline  \
# 0  पठानकोट पहुंचे PM मोदी, एयरबेस का जायजा ले बॉर...
# 1  सचिन ने देशवासियों को समर्पित किया अपना दोहरा शतक
# 2  एनआईए करेगी छत्तीसगढ़ में सुरक्षा खामियों की ज...
# 3  सीधी बात:  शाह बोले- हमारा बस चलता तो अब तक मं...
# 4  ऋषभ पंत के पास यूनिक टैलेंट, उसके साथ छेड़छाड़ न...
#
#                                              article
# 0  प्रधानमंत्री नरेंद्र मोदी पठानकोट एयरबेस पहुंच...
# 1  सचिन तेंदुलकर ने एकदिवसीय अंतरराष्ट्रीय क्रिके...
# 2  केंद्रीय गृह राज्य मंत्री आर. पी. एन. सिंह ने ...
# 3  भारतीय जनता पार्टी (बीजेपी) के राष्ट्रीय अध्यक...
# 4  ऋषभ पंत की कभी कभार इस बात के लिए आलोचना की जा...

# %%
from regex_tokenizer import RegexTokenizer

reg_tokenizer = RegexTokenizer()
reg_tokenizer.train(sample_text, verbose=True, vocab_size=50257)

# %%
import pickle

filename = 'reg_tokenizer.pkl'

with open(filename, 'wb') as f:
    pickle.dump(reg_tokenizer, f)

# %%
# checking gpt tokenizer
import tiktoken
gpt_tokenizer = tiktoken.get_encoding("o200k_base")

text2 = "Many words map to one token, but some don't: indivisible. Unicode characters like emojis may be split into many tokens containing the underlying bytes"

en = gpt_tokenizer.encode(text2)
print(en)
print(len(en))

dc = gpt_tokenizer.decode([12488, 6391, 4014, 316, 1001, 6602, 11, 889, 1236, 4128, 25, 3862, 181386, 13, 77402, 9862, 1299, 166700, 1340, 413, 12648, 1511, 1991, 20290, 15683, 290, 27899, 11643])
print(dc)
print(len(dc))
# Out:
# [12488, 6391, 4014, 316, 1001, 6602, 11, 889, 1236, 4128, 25, 3862, 181386, 13, 77402, 9862, 1299, 166700, 1340, 413, 12648, 1511, 1991, 20290, 15683, 290, 27899, 11643]
# 28
# Many words map to one token, but some don't: indivisible. Unicode characters like emojis may be split into many tokens containing the underlying bytes
# 150

# %%
from hindi_tokenizer import HINDI_SPLIT_PATTERN, normalize_text
from regex_tokenizer import GPT4_SPLIT_PATTERN
import re

compiled_pattern = re.compile(HINDI_SPLIT_PATTERN)

text = "रा\u0937\u094Dट्रीय सुरक्षा सलाहकार नासिर खान जंजुआ को भारत के एनएसए अजित |"
text = normalize_text(text)

tokens = re.findall(compiled_pattern, text)
print(tokens)
# Out:
# ['राष्ट्रीय', ' ', 'सुरक्षा', ' ', 'सलाहकार', ' ', 'नासिर', ' ', 'खान', ' ', 'जंजुआ', ' ', 'को', ' ', 'भारत', ' ', 'के', ' ', 'एनएसए', ' ', 'अजित', ' ', '|']

# %%
from regex_tokenizer import RegexTokenizer

hindi_tokenizer = RegexTokenizer(HINDI_SPLIT_PATTERN)
sample_train_text = normalize_text(sample_train_text)

# %%
hindi_tokenizer.train(sample_train_text, verbose=True)
# Out:
# merge 1/20: (224, 164) -> 256 (b'\xe0\xa4' had 4931 occurences)
# merge 2/20: (224, 165) -> 257 (b'\xe0\xa5' had 1350 occurences)
# merge 3/20: (256, 190) -> 258 (b'\xe0\xa4\xbe' had 552 occurences)
# merge 4/20: (257, 135) -> 259 (b'\xe0\xa5\x87' had 471 occurences)
# merge 5/20: (256, 149) -> 260 (b'\xe0\xa4\x95' had 449 occurences)
# merge 6/20: (256, 176) -> 261 (b'\xe0\xa4\xb0' had 419 occurences)
# merge 7/20: (256, 130) -> 262 (b'\xe0\xa4\x82' had 293 occurences)
# merge 8/20: (256, 168) -> 263 (b'\xe0\xa4\xa8' had 280 occurences)
# merge 9/20: (256, 185) -> 264 (b'\xe0\xa4\xb9' had 277 occurences)
# merge 10/20: (256, 184) -> 265 (b'\xe0\xa4\xb8' had 262 occurences)
# merge 11/20: (257, 128) -> 266 (b'\xe0\xa5\x80' had 259 occurences)
# merge 12/20: (32, 32) -> 267 (b'  ' had 253 occurences)
# merge 13/20: (256, 164) -> 268 (b'\xe0\xa4\xa4' had 229 occurences)
# merge 14/20: (257, 141) -> 269 (b'\xe0\xa5\x8d' had 226 occurences)
# ...

# %%
import pickle

filename = 'hindi_tokenizer.pkl'

with open(filename, 'wb') as f:
    pickle.dump(reg_tokenizer, f)
